# %% [markdown]
# <a href="https://colab.research.google.com/github/sean950722/hello/blob/main/%E3%80%8CEX03_03_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 讀取網路上的 CSV 檔
import pandas as pd
url = 'https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=9e565f9a-84dd-4e79-9097-d403cae1ea75&limit=1000&sort=ImportDate%20desc&format=CSV'
df = pd.read_csv(url)
df.head()
# Out:
#   sitename county  aqi pollutant    status  so2    co    o3  o3_8hr   pm10  \
# 0       基隆    基隆市   93      懸浮微粒        普通  NaN   NaN  79.0      59   67.0
# 1       汐止    新北市  101      懸浮微粒  對敏感族群不健康  1.8  0.22  76.0      49   75.0
# 2       萬里    新北市  109      懸浮微粒  對敏感族群不健康  1.2  0.32  81.0      67  102.0
# 3       新店    新北市  102      懸浮微粒  對敏感族群不健康  1.6  0.33  75.0      52   82.0
# 4       土城    新北市  104      懸浮微粒  對敏感族群不健康  1.3  0.28  76.0      49   81.0
#
#    ...  wind_speed  wind_direc          publishtime  co_8hr pm2.5_avg  \
# 0  ...         4.4          89  2025/04/15 14:00:00     0.2      20.7
# 1  ...         2.4          11  2025/04/15 14:00:00     0.2      20.1
# 2  ...         4.3          70  2025/04/15 14:00:00     0.3      19.0
# 3  ...         2.7           8  2025/04/15 14:00:00     0.3      18.2
# 4  ...         2.7          62  2025/04/15 14:00:00     0.3      21.9
#
#   pm10_avg so2_avg   longitude   latitude  siteid
# 0       69       2  121.760056  25.129167       1
# 1       76       1  121.640810  25.066240       2
# 2       94       1  121.689881  25.179667       3
# 3       79       1  121.537778  24.977222       4
# 4       83       1  121.451861  24.982528       5
#
# [5 rows x 24 columns]

# %% [markdown]
# ###留下需要的欄位（'sitename', 'county','pollutant', 'status', 'aqi'）

# %%
df= df[['sitename', 'county','pollutant', 'status', 'aqi']]
df
# Out:
#        sitename county pollutant    status  aqi
# 0            基隆    基隆市      懸浮微粒        普通   93
# 1            汐止    新北市      懸浮微粒  對敏感族群不健康  101
# 2            萬里    新北市      懸浮微粒  對敏感族群不健康  109
# 3            新店    新北市      懸浮微粒  對敏感族群不健康  102
# 4            土城    新北市      懸浮微粒  對敏感族群不健康  104
# ..          ...    ...       ...       ...  ...
# 82       屏東（琉球）    屏東縣      懸浮微粒  對敏感族群不健康  120
# 83  台中市（和平區消防隊）    臺中市      懸浮微粒  對敏感族群不健康  104
# 84       新北（樹林）    新北市      懸浮微粒  對敏感族群不健康  104
# 85       臺南（南化）    臺南市      懸浮微粒        普通   91
# 86       屏東(枋山)    屏東縣        臭氧  對敏感族群不健康  108
#
# [87 rows x 5 columns]

# %% [markdown]
# ###請找出除了空氣品質不良的測站（aqi > 100）

# %%
conditon= df['aqi']>100
df[conditon]
# Out:
#        sitename county pollutant    status  aqi
# 1            汐止    新北市      懸浮微粒  對敏感族群不健康  101
# 2            萬里    新北市      懸浮微粒  對敏感族群不健康  109
# 3            新店    新北市      懸浮微粒  對敏感族群不健康  102
# 4            土城    新北市      懸浮微粒  對敏感族群不健康  104
# 5            板橋    新北市      懸浮微粒  對敏感族群不健康  103
# ..          ...    ...       ...       ...  ...
# 81       臺南（麻豆）    臺南市      懸浮微粒  對敏感族群不健康  114
# 82       屏東（琉球）    屏東縣      懸浮微粒  對敏感族群不健康  120
# 83  台中市（和平區消防隊）    臺中市      懸浮微粒  對敏感族群不健康  104
# 84       新北（樹林）    新北市      懸浮微粒  對敏感族群不健康  104
# 86       屏東(枋山)    屏東縣        臭氧  對敏感族群不健康  108
#
# [82 rows x 5 columns]

# %% [markdown]
# ###查詢空氣污染指標物（pollutant）有那些？

# %%
df['pollutant'].unique()
# Out:
# array(['懸浮微粒', '細懸浮微粒', '臭氧八小時', '臭氧'], dtype=object)

# %% [markdown]
# ###請找出高雄市的測站資料

# %%
conditon= df['county']=='高雄市'
df[conditon]
# Out:
#    sitename county  aqi pollutant    status  so2    co    o3  o3_8hr   pm10  \
# 46       美濃    高雄市   84      懸浮微粒        普通  0.9  0.16  67.0      46   78.0
# 47       橋頭    高雄市  110      懸浮微粒  對敏感族群不健康  1.4  0.20  80.0      54  127.0
# 48       仁武    高雄市  110      懸浮微粒  對敏感族群不健康  2.3  0.25  87.0      54  113.0
# 49       鳳山    高雄市  115      懸浮微粒  對敏感族群不健康  2.4  0.39  79.0      55  107.0
# 50       大寮    高雄市  107      懸浮微粒  對敏感族群不健康  2.2  0.33  84.0      54  113.0
# 51       林園    高雄市  112      懸浮微粒  對敏感族群不健康  2.1  0.19  80.0      56   97.0
# 52       楠梓    高雄市  113      懸浮微粒  對敏感族群不健康  1.3  0.21  78.0      54  129.0
# 53       左營    高雄市  114      懸浮微粒  對敏感族群不健康  NaN   NaN   NaN      55  133.0
# 54       前金    高雄市  114      懸浮微粒  對敏感族群不健康  1.9  0.25  79.0      59  120.0
# 55       前鎮    高雄市  122      懸浮微粒  對敏感族群不健康  4.1  0.27  79.0      60  170.0
# 56       小港    高雄市  111      懸浮微粒  對敏感族群不健康  4.1  0.22  73.0      53  106.0
# 69       復興    高雄市  110      懸浮微粒  對敏感族群不健康  2.6  0.26  70.0      57  115.0
# 80   高雄（湖內）    高雄市  109      懸浮微粒  對敏感族群不健康  NaN  0.20  70.0      45  110.0
#
#     ...  wind_speed  wind_direc          publishtime  co_8hr pm2.5_avg  \
# 46  ...         1.1          80  2025/04/15 14:00:00     0.1      17.0
# 47  ...         3.5         270  2025/04/15 14:00:00     0.2      28.0
# 48  ...         3.9         272  2025/04/15 14:00:00     0.3      25.5
# 49  ...         1.6         293  2025/04/15 14:00:00     0.4      28.5
# 50  ...         2.8         252  2025/04/15 14:00:00     0.2      22.4
# 51  ...           3         280  2025/04/15 14:00:00     0.2      30.2
# 52  ...           3         273  2025/04/15 14:00:00     0.2      23.5
# 53  ...         NaN         NaN  2025/04/15 14:00:00     0.2      26.8
# 54  ...         3.7         354  2025/04/15 14:00:00     0.2      26.9
# 55  ...         1.8         273  2025/04/15 14:00:00     0.3      27.1
# 56  ...         4.2         266  2025/04/15 14:00:00     0.3      27.9
# 69  ...           1         216  2025/04/15 14:00:00     0.4      26.3
# 80  ...         1.5         315  2025/04/15 14:00:00     0.2      23.4
#
#    pm10_avg so2_avg   longitude   latitude  siteid
# 46       61       0  120.530542  22.883583      47
# 47       98       1  120.305689  22.757506      48
# 48       97       1  120.332631  22.689056      49
# 49      108       2  120.357422  22.628126      50
# 50       90       4  120.425311  22.564136      51
# 51      101       2  120.411750  22.479500      52
# 52      104       1  120.328289  22.733667      53
# 53      106       0  120.292917  22.674861      54
# 54      106       0  120.286761  22.633903      56
# 55      125       1  120.308334  22.604451      57
# 56       99       2  120.337736  22.565833      58
# 69       98       1  120.312017  22.608711      71
# 80       94       1  120.245350  22.879856     202
#
# [13 rows x 24 columns]

# %% [markdown]
# ###計算各縣市的平均 AQI

# %%
df.groupby('county')['aqi'].mean().sort_values(ascending=False)
# Out:
# county
# 金門縣    136.000000
# 澎湖縣    119.000000
# 嘉義縣    116.000000
# 彰化縣    115.400000
# 雲林縣    115.250000
# 臺中市    114.166667
# 苗栗縣    112.666667
# 新竹縣    112.500000
# 嘉義市    112.000000
# 新竹市    111.000000
# 臺南市    110.500000
# 高雄市    110.076923
# 桃園市    110.000000
# 連江縣    109.000000
# 南投縣    107.666667
# 屏東縣    106.600000
# 新北市    105.615385
# 宜蘭縣    104.333333
# 花蓮縣    104.000000
# 臺北市    104.000000
# 基隆市     93.000000
# 臺東縣     88.500000
# Name: aqi, dtype: float64
